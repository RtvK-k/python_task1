# %%
print("Enter 'stop' to end the loop")
while True:
    letter = input("Enter Letter: ")
    letter = letter.upper()
    if letter == 'A':
        print("\n* * * * * *\n*         *\n*         *\n* * * * * *\n*         *\n*         *\n*         * ")
    elif letter == 'B':
        print("\n* * * *  \n*      * \n*      * \n* * * *  \n*       *\n*       *\n*       *\n* * * *  ")
    elif letter == 'C':
        print("\n* * * * *\n*         \n*         \n*         \n*         \n* * * * *")
    elif letter == 'D':
        print("\n* * * * *   \n*         * \n*         * \n*         * \n*         * \n*         * \n* * * * *   ")
    elif letter == 'E':  
        print("\n* * * * *  \n*         \n*         \n* * * * * \n*         \n*         \n* * * * * ")
    elif letter == 'F':
        print("\n* * * * *\n*        \n*        \n* * * * *\n*        \n*        \n*        \n")
    elif letter == 'G':
        print("\n  * * * * *\n*          \n*          \n*          \n*     * * *\n*         *\n*         *\n  * * * *  ")
    elif letter == 'H':
        print("\n*       *\n*       *\n*       *\n* * * * *\n*       *\n*       *\n*       *")  
    elif letter == 'I':
        print("\n* * * * *\n    *    \n    *    \n    *    \n    *    \n    *    \n* * * * *") 
    elif letter == 'J':
        print("\n  * *  *\n       *\n       *\n       *\n       *\n*      *\n* * * *  \n")
    elif letter == 'K':
        print("\n*       *\n*     *  \n*   *    \n* *      \n* *      \n*   *    \n*     *  \n*       *")  
    elif letter == 'L':  
        print("\n*          \n*          \n*          \n*          \n*          \n*          \n* * * * *")
    elif letter == 'M':
        print("\n*         *\n* *     * *\n*  *   *  *\n*   * *   *\n*    *    *\n*         *\n*         *")    
    elif letter == 'N':
        print("\n*         *\n* *       *\n*  *      *\n*   *     *\n*    *    *\n*     *   *\n*       * *\n*         *")    
    elif letter == 'O':
        print("\n  * * * *  \n*         *\n*         *\n*         *\n*         *\n*         *\n  * * * *  \n")
    elif letter == 'P':
        print("\n* * * * *\n*       *\n*       *\n* * * * *\n*        \n*        \n*        \n*        ")   
    elif letter == 'Q':
        print("\n * * * *    \n*       *  \n*       *  \n*       *  \n*       *  \n*       *  \n * * * *  \n        * *")
    elif letter == 'R':
        print("\n* * * *  \n*       *\n*       *\n* * * *  \n*    *   \n*     *  \n*      * \n*       *")
    elif letter == 'S':  
        print("\n  * * * *\n*        \n*        \n * * * * \n        *\n        *\n* * * *  ")
    elif letter == 'T':
        print("\n* * * * *\n    *   \n    *   \n    *   \n    *   \n    *   ")
    elif letter == 'U':
        print("\n*       *\n*       *\n*       *\n*       *\n*       *\n  * * *  ")
    elif letter == 'V':
        print("\n*         *\n *       * \n  *     *  \n   *   *   \n    * *    \n     *     ")
    elif letter == 'W':
        print("\n*           *\n*           *\n*     *     *\n*     *     *\n *   * *   * \n  * *   * *  \n")
    elif letter == 'X':
        print("\n*         *\n  *     *  \n    * *    \n     *     \n    * *    \n  *     *  \n*         *")
    elif letter == 'Y': 
        print("\n*       *\n *     *\n  *   *\n   * *\n    *\n    *\n    *")
    elif letter =='Z' :
        print("\n* * * * * *\n         * \n       *   \n     *     \n   *       \n *         \n* * * * * *")
    elif letter == 'STOP':
        break
    else:
        print("Incorrect input, Try Again")
